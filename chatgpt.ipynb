# %%
# DATA PREPROCESSING

import pandas as pd  
import numpy as np
import re                                 
import spacy                              
from langdetect import detect
from langdetect.lang_detect_exception import LangDetectException        

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# %%
# Load the dataset
df = pd.read_csv(r'c:\Users\Thennarasu\OneDrive\Documents\dataset\chatgpt_style_reviews_dataset.xlsx - Sheet1.csv')

# %%
# Show basic info
df
# Out:
#           date                                              title  \
# 0   2024-12-24   East list local interesting far magazine father.
# 1   2024-07-26  Road determine picture figure hard experience ...
# 2   2024-08-22                 Policy social past analysis whole.
# 3   2025-04-24               News financial billion four foreign.
# 4   2024-08-15                To skill she case sing stop likely.
# 5   2024-07-04                        Involve office space crime.
# 6   2024-08-13        American wait board improve there court TV.
# 7   2025-02-22  Control drop economic easy ability become figure.
# 8   2024-12-12            Pick rock body stuff off model brother.
# 9   2025-02-23   School involve teach rather long value director.
# 10  2025-03-07              Whole last control second forward Mr.
# 11  2025-04-04                       Provide move provide forget.
# 12  2024-12-15                          Minute environment blood.
# 13  2024-09-28             Tough develop else lose trade however.
# 14  2025-06-12           Right several energy couple help street.
# 15  2025-03-30                                Guy turn until boy.
# 16  2024-10-21               Left cultural it ten affect general.
# 17  2025-05-16  Thousand recent reveal likely son natural less...
# 18  2024-12-23                  Detail bar support military hair.
# 19  2025-03-15                   Drive shoulder room family data.
# 20  2025-02-12                Door shake thank worker old accept.
# 21  2025-02-20                    Most our along later executive.
# 22  2025-04-10                                   Keep treat many.
# 23  2025-06-09  That training line anyone organization beautiful.
# 24  2024-12-14            Body road model kitchen that radio act.
# 25  2024-12-19                     Why plant either interest yes.
# 26  2024-12-08        Such spring else all good identify car tax.
# 27  2025-04-21       Individual still such sometimes market to a.
# 28  2024-08-27     Wait authority little final consider movement.
# 29  2024-10-18           Anyone every any authority cover though.
# 30  2025-05-28  Local recent serious plan media benefit certai...
# 31  2025-04-04                              White able bank base.
# 32  2025-03-28                        Field state evidence enter.
# 33  2025-03-29         Staff person person idea fall leader yeah.
# 34  2024-10-13             Sense though where move nation nearly.
# 35  2024-10-26      State side thought those turn toward make my.
# 36  2025-01-15                   Fear story parent direction son.
# 37  2025-04-21  Collection term show statement about wish impact.
# 38  2024-12-31          Ability keep organization total maintain.
# 39  2024-08-02       Will law machine director good thought much.
# 40  2024-07-02                               Fear executive rest.
# 41  2024-07-26     Wear sign see child tonight effect himself Mr.
# 42  2025-05-12                    Try laugh against modern class.
# 43  2024-08-15         Book how begin son expert standard result.
# 44  2024-07-05                Successful far use usually million.
# 45  2024-11-09       Especially local minute worry sit religious.
# 46  2025-02-11             Because mouth expect turn control win.
# 47  2025-01-01       Early at where sure kid computer over stand.
# 48  2024-10-14                   Skill off agree together person.
# 49  2025-03-11                             White use return time.
#
#                                                review  rating  \
# 0   Impressive natural language understanding. Alm...       1
# 1   Sometimes gives wrong answers or outdated info...       2
# 2   Great tool for generating content quickly. Int...       5
# 3   Great tool for generating content quickly. Sta...       3
# 4   Excellent for language translation and grammar...       1
# 5   Explains complex topics clearly and simply. De...       4
# 6   Excellent for language translation and grammar...       2
# 7   Sometimes gives wrong answers or outdated info...       3
# 8   Sometimes gives wrong answers or outdated info...       1
# 9   Very helpful for coding and debugging tasks. S...       2
# 10  Impressive natural language understanding. Dur...       2
# 11  Good for summarizing large documents. Help fro...       2
# 12  Responses could be faster in peak hours. They ...       1
# 13  Good for summarizing large documents. Hospital...       3
# 14  Good for summarizing large documents. Piece wa...       5
# 15  Responses could be faster in peak hours. Clear...       3
# 16  Impressive natural language understanding. Inf...       2
# 17  Very helpful for coding and debugging tasks. O...       5
# 18  Great tool for generating content quickly. Enj...       2
# 19  Impressive natural language understanding. Per...       5
# 20  Very helpful for coding and debugging tasks. S...       3
# 21  Sometimes lacks context in long conversations....       4
# 22  Excellent for language translation and grammar...       3
# 23  Explains complex topics clearly and simply. Re...       4
# 24  Needs improvement in handling very technical q...       5
# 25  Sometimes gives wrong answers or outdated info...       5
# 26  Great tool for generating content quickly. Dif...       2
# 27  Sometimes gives wrong answers or outdated info...       2
# 28  Needs improvement in handling very technical q...       3
# 29  Sometimes lacks context in long conversations....       1
# 30  Explains complex topics clearly and simply. Al...       3
# 31  Great tool for generating content quickly. Occ...       3
# 32  Good for summarizing large documents. Far firs...       3
# 33  Responses could be faster in peak hours. Becom...       5
# 34  Good for summarizing large documents. Unit rec...       2
# 35  Great tool for generating content quickly. Int...       4
# 36  Good for summarizing large documents. Put auth...       4
# 37  Sometimes lacks context in long conversations....       2
# 38  Excellent for language translation and grammar...       1
# 39  Good for summarizing large documents. Thousand...       2
# 40  Explains complex topics clearly and simply. Se...       5
# 41  Responses could be faster in peak hours. Milit...       2
# 42  Great tool for generating content quickly. Ten...       3
# 43  Explains complex topics clearly and simply. Mo...       1
# 44  Needs improvement in handling very technical q...       5
# 45  Great tool for generating content quickly. Eve...       4
# 46  Good for summarizing large documents. Senior v...       4
# 47  Explains complex topics clearly and simply. Pr...       3
# 48  Sometimes gives wrong answers or outdated info...       3
# 49  Great tool for generating content quickly. Imp...       5
#
#             username  helpful_votes  review_length     platform language  \
# 0           darren55             25              9  Google Play       de
# 1         davistyler             35             14     Flipkart       es
# 2           andrea59             94             10    App Store       es
# 3            dcooper             50             15       Amazon       de
# 4        christine79             33             11     Flipkart       fr
# 5            qfields             29             12     Flipkart       fr
# 6            david89             45             10    App Store       en
# 7             mark52             77             12    App Store       en
# 8             glewis             66             13  Google Play       de
# 9      davispatricia             33             19    App Store       en
# 10        vcarpenter             86             10    App Store       fr
# 11          andrea65             54             10    App Store       es
# 12      millerlauren             99             16  Google Play       es
# 13             don30             88             16     Flipkart       de
# 14         adamdoyle             73             10       Amazon       en
# 15           ethan46             86             19       Amazon       en
# 16         awilliams             89              9     Flipkart       fr
# 17     taylorkatelyn             19             10    App Store       fr
# 18      beltranmegan             19             21  Google Play       en
# 19             blang             84              7     Flipkart       fr
# 20    mcclaingregory             63             14    App Store       en
# 21         matthew75             69             10       Amazon       en
# 22            hhicks             25             11     Flipkart       en
# 23           ugraves             59             14       Amazon       de
# 24        benjamin65             59             14     Flipkart       es
# 25   jamesmccullough             70             18    App Store       fr
# 26        vargastina             90             19       Amazon       es
# 27        stonelarry             52             11       Amazon       en
# 28        youngemily             77             14       Amazon       es
# 29          dillon46             60             19  Google Play       en
# 30        irodriguez             57             13    App Store       en
# 31            bjones             85             13    App Store       en
# 32     victoriaburns             47             16     Flipkart       fr
# 33       edgarmorris             62             19       Amazon       de
# 34            gbrown             63             12     Flipkart       en
# 35     trevorvazquez             37             13    App Store       fr
# 36     derekgonzalez             63              9  Google Play       en
# 37            gpatel              9             15       Amazon       fr
# 38  rodriguezmadison             62             16     Flipkart       es
# 39         bmartinez             95             14  Google Play       es
# 40            psmith             93             10  Google Play       en
# 41        benjamin17             45             20     Flipkart       en
# 42           sarah01             88             12    App Store       fr
# 43    margaretgolden             92             18     Flipkart       fr
# 44            cellis             94             11     Flipkart       es
# 45    stevenmitchell             47             17    App Store       de
# 46  stevensonkenneth             30             13    App Store       en
# 47          leejames             90             10       Amazon       fr
# 48        kimberly89             26             13     Flipkart       en
# 49    ashleywilliams             23              9  Google Play       de
#
#                                         location version verified_purchase
# 0                                          Nepal   2.0.4                No
# 1                                         Panama   2.6.5                No
# 2                                        Denmark   4.2.2                No
# 3                              Brunei Darussalam   4.4.2                No
# 4           United States Minor Outlying Islands   5.1.1               Yes
# 5                                          Spain   2.1.5               Yes
# 6                                         Kuwait   3.2.7                No
# 7                            Antigua and Barbuda   5.7.2                No
# 8                                      Hong Kong   5.7.8               Yes
# 9                              Brunei Darussalam   4.0.6                No
# 10                                     Guatemala   3.2.0               Yes
# 11                                    Seychelles   2.7.1               Yes
# 12                                 French Guiana   1.1.3                No
# 13  South Georgia and the South Sandwich Islands   2.2.4               Yes
# 14                                   Switzerland   3.6.7                No
# 15                                 Faroe Islands   2.7.1                No
# 16                                 Liechtenstein   4.7.6                No
# 17                                 Cote d'Ivoire   4.6.2                No
# 18                                        Mexico   1.0.1                No
# 19                                   Isle of Man   1.5.8                No
# 20                                    Mozambique   5.0.1                No
# 21                                         Macao   3.4.4                No
# 22                                   Isle of Man   3.8.2               Yes
# 23                        Libyan Arab Jamahiriya   4.2.8                No
# 24                      Turks and Caicos Islands   3.6.5                No
# 25                                          Togo   5.5.3                No
# 26                                        Angola   1.3.8                No
# 27                                    Micronesia   2.5.5                No
# 28                                       Germany   1.7.4               Yes
# 29                                       Lesotho   2.2.5               Yes
# 30                                       Somalia   1.2.4               Yes
# 31                                        Mexico   3.2.9               Yes
# 32                                      Guernsey   2.0.6               Yes
# 33                                       Algeria   3.9.6                No
# 34                                       Armenia   2.6.6               Yes
# 35                                 Liechtenstein   3.6.1                No
# 36                                         Nepal   3.4.6               Yes
# 37                                         Korea   2.0.1               Yes
# 38                                       Morocco   5.1.7                No
# 39                                       Denmark   2.1.1                No
# 40                                       Denmark   5.1.1               Yes
# 41                                     Nicaragua   3.9.9               Yes
# 42                                          Fiji   1.1.6               Yes
# 43                                   New Zealand   1.0.9                No
# 44                                    San Marino   3.3.8               Yes
# 45                                         Sudan   3.6.0                No
# 46                                         Macao   2.9.9                No
# 47                                    Martinique   1.5.3               Yes
# 48                              Pitcairn Islands   2.8.0                No
# 49                                       Austria   2.7.7                No

# %%
# row and column 

df.shape
# Out:
# (50, 12)

# %%
print(df.isnull().sum())
# Out:
# date                 0
# title                0
# review               0
# rating               0
# username             0
# helpful_votes        0
# review_length        0
# platform             0
# language             0
# location             0
# version              0
# verified_purchase    0
# dtype: int64

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
## remove whitespace

def remove_whitespace(text):
    return " ".join(text.split())

df['review']=df['review'].apply(remove_whitespace)

# %%
# Language Detection

def detect_language(text):
    try:
        return detect(text)
    except LangDetectException:
        return "unknown"

df['detect_language'] = df['review'].apply(detect_language)

# Filter only English reviews
df = df[df['detect_language'] == 'en']
print(df['detect_language'].value_counts())
# Out:
# detect_language
# en    50
# Name: count, dtype: int64

# %%
# Basic Text Cleaning

def clean_text(text):
    
    # Remove non-alphabetic characters (keep spaces)

    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Convert to lowercase
    text = text.lower()
    return text

df['review'] = df['review'].apply(clean_text)

# %%
# Tokenization + Lemmatization + Stopword Removal with spaCy

def spacy_preprocess(text):
    doc = nlp(text)
    tokens = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(tokens)

df['review'] = df['review'].apply(spacy_preprocess)
df['review']
# Out:
# 0     impressive natural language understanding good...
# 1     give wrong answer outdated info student moveme...
# 2     great tool generate content quickly interestin...
# 3     great tool generate content quickly start meth...
# 4     excellent language translation grammar fix pri...
# 5     explain complex topic clearly simply detail vi...
# 6     excellent language translation grammar fixes f...
# 7     give wrong answer outdated info catch easy inc...
# 8     give wrong answer outdated info trial suffer p...
# 9     helpful code debug task tax hard thousand envi...
# 10    impressive natural language understanding cour...
# 11    good summarize large document help opportunity...
# 12    response fast peak hour develop old network mo...
# 13    good summarize large document hospital wide re...
# 14       good summarize large document piece watch head
# 15    response fast peak hour clear meeting serve au...
# 16    impressive natural language understand informa...
# 17                  helpful code debug task option past
# 18    great tool generate content quickly enjoy stop...
# 19       impressive natural language understanding term
# 20    helpful code debug task strategy process oppor...
# 21    lack context long conversation low fight natur...
# 22    excellent language translation grammar fix lat...
# 23    explain complex topic clearly simply ready col...
# 24    need improvement handle technical query paint ...
# 25    give wrong answer outdated info family behavio...
# 26    great tool generate content quickly different ...
# 27    give wrong answer outdated info blue recognize...
# 28    need improvement handle technical query art ne...
# 29    lack context long conversation raise term fund...
# 30    explain complex topic clearly simply finish ce...
# 31    great tool generate content quickly occur matt...
# 32    good summarize large document far city figure ...
# 33    response fast peak hour pattern college game d...
# 34    good summarize large document unit receive tea...
# 35    great tool generate content quickly internatio...
# 36    good summarize large document authority main a...
# 37    lack context long conversation loss entire age...
# 38    excellent language translation grammar fix tho...
# 39    good summarize large document thousand discuss...
# 40    explain complex topic clearly simply service s...
# 41    response fast peak hour military pass total gr...
# 42    great tool generate content quickly image poli...
# 43    explain complex topic clearly simply movie add...
# 44    need improvement handle technical query gas ch...
# 45    great tool generate content quickly huge yard ...
# 46    good summarize large document senior voice sta...
# 47    explain complex topic clearly simply property ...
# 48    give wrong answer outdated info argue life yea...
# 49    great tool generate content quickly important ...
# Name: review, dtype: object

# %%
# Replace newlines (\n) and extra spaces around them with a single space

df['review'] = df['review'].str.replace(r'\s*\n\s*', ' ', regex=True)

# %%
## read column name of entire dataset

df.columns
# Out:
# Index(['date', 'title', 'review', 'rating', 'username', 'helpful_votes',
#        'review_length', 'platform', 'language', 'location', 'version',
#        'verified_purchase', 'detect_language'],
#       dtype='object')

# %%
# EXPLORATORY DATA ANALYSIS (EDA)

import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer

# %%
# 1. What is the distribution of review ratings? 
# Set Seaborn style
sns.set(style="whitegrid")

# Plot the distribution of review ratings
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='rating', palette='coolwarm')
plt.title('Distribution of Review Ratings')
plt.xlabel('Rating (1 to 5 stars)')
plt.ylabel('Number of Reviews')
plt.xticks([0, 1, 2, 3, 4], ['1 Star', '2 Stars', '3 Stars', '4 Stars', '5 Stars'])
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Thennarasu\AppData\Local\Temp\ipykernel_3088\3135755171.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='rating', palette='coolwarm')

# %%
# 2. How many reviews were marked as helpful (above a certain threshold)?

# Define threshold
threshold = 10

# Count helpful vs not helpful
helpful_counts = pd.Series([
    'Helpful (10+)' if x > threshold else 'Not Helpful' 
    for x in df['helpful_votes']
]).value_counts()

# Plot pie chart
plt.figure(figsize=(6, 6))
colors = ['#66c2a5', '#fc8d62']
helpful_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Helpful vs Not Helpful Reviews (Threshold: >10 votes)')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
# 3. Most Common Keywords in Positive vs. Negative Reviews

# Filter based on ratings
positive_reviews = df[df['rating'] >= 3]['review']
negative_reviews = df[df['rating'] <= 2]['review']

# Join all text
positive_text = ' '.join(positive_reviews.dropna().astype(str))
negative_text = ' '.join(negative_reviews.dropna().astype(str))

# Create word clouds
plt.figure(figsize=(14, 6))

# Positive word cloud
plt.subplot(1, 2, 1)
wordcloud_pos = WordCloud(width=600, height=400, background_color='white', colormap='Greens').generate(positive_text)
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis('off')
plt.title("Positive Reviews (3–5 stars)", fontsize=14)

# Negative word cloud
plt.subplot(1, 2, 2)
wordcloud_neg = WordCloud(width=600, height=400, background_color='white', colormap='Reds').generate(negative_text)
plt.imshow(wordcloud_neg, interpolation='bilinear')
plt.axis('off')
plt.title("Negative Reviews (1–2 stars)", fontsize=14)

plt.tight_layout()
plt.show()

# %%
# 4. How has the average rating changed over time?

# Convert date column to datetime format 
df['date'] = pd.to_datetime(df['date'])

# Group by time — weekly or monthly
avg_rating_over_time = df.groupby(df['date'].dt.to_period('M'))['rating'].mean().reset_index()
avg_rating_over_time['date'] = avg_rating_over_time['date'].dt.to_timestamp()

# Plot the line chart
plt.figure(figsize=(10, 5))
plt.plot(avg_rating_over_time['date'], avg_rating_over_time['rating'], marker='o', linestyle='-')
plt.title('Average Review Rating Over Time')
plt.xlabel('Date')
plt.ylabel('Average Rating')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 5. How Do Ratings Vary by User Location?

# Top 10 countries by review count
top_countries = df['location'].value_counts().nlargest(10).index
filtered_df = df[df['location'].isin(top_countries)]

# Average rating by location
avg_rating_by_location = filtered_df.groupby('location')['rating'].mean().sort_values(ascending=False)

# Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=avg_rating_by_location.values, y=avg_rating_by_location.index, palette="coolwarm")
plt.xlabel('Average Rating')
plt.title('Average Review Ratings by Location (Top 10)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Thennarasu\AppData\Local\Temp\ipykernel_3088\1801664226.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_rating_by_location.values, y=avg_rating_by_location.index, palette="coolwarm")

# %%
# 6. Which Platform Gets Better Reviews? (Web vs. Mobile)

# Group by platform and calculate average ratings
avg_rating_by_platform = df.groupby('platform')['rating'].mean().reset_index()

# Bar chart
plt.figure(figsize=(6, 4))
sns.barplot(x='platform', y='rating', data=avg_rating_by_platform, palette='Set2')
plt.title('Average Rating by Platform (Web vs Mobile)')
plt.ylabel('Average Rating')
plt.xlabel('Platform')
plt.ylim(0, 5)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Thennarasu\AppData\Local\Temp\ipykernel_3088\4079748808.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='platform', y='rating', data=avg_rating_by_platform, palette='Set2')

# %%
# 7. Are Verified Users More Satisfied Than Non-Verified Ones?

# Distribution of Verified vs Non-Verified Reviews
verified_counts = df['verified_purchase'].value_counts()

# Plotting side-by-side pie charts
plt.figure(figsize=(12, 6))
colors = ['#66c2a5', '#fc8d62']

# Subplot 1: Review count
plt.subplot(1, 2, 1)
verified_counts.plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    labels=verified_counts.index,
    wedgeprops={'edgecolor': 'white'}
)
plt.title('Review Count: Verified vs Non-Verified')
plt.ylabel('');

# %%
# 8. Average Length of Reviews per Rating Category

# Bar Chart: Average Review Length by Rating
plt.figure(figsize=(8, 5))
sns.barplot(x='rating', y='review_length', data=df, palette='Blues')
plt.title('Average Review Length per Rating')
plt.xlabel('Rating')
plt.ylabel('Review Length (Word Count)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Thennarasu\AppData\Local\Temp\ipykernel_3088\2251875569.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='rating', y='review_length', data=df, palette='Blues')

# %%
# 9. Most Mentioned Words in 1-Star Reviews

# Filter 1-star reviews
one_star_text = ' '.join(df[df['rating'] == 1]['review'].dropna().astype(str))

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='Reds').generate(one_star_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Words in 1-Star Reviews')
plt.tight_layout()
plt.show()

# %%
# 10. Which ChatGPT Version Received the Highest Average Rating?

# Group by version and calculate average rating
version_avg = df.groupby('version')['rating'].mean().sort_values(ascending=False).reset_index()

# Bar plot: Versions vs average ratings
plt.figure(figsize=(10, 5))
sns.barplot(x='version', y='rating', data=version_avg, palette='viridis')
plt.title('Average Rating by ChatGPT Version')
plt.xlabel('Version')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.ylim(0, 5)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Thennarasu\AppData\Local\Temp\ipykernel_3088\1045151504.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='version', y='rating', data=version_avg, palette='viridis')

# %%
# Sentiment Labeling

def label_sentiment(rating):
    if rating <= 2:
        return 'negative'
    elif rating == 3:
        return 'neutral'
    else:
        return 'positive'

df['sentiment'] = df['rating'].apply(label_sentiment)
print(df[['rating', 'sentiment']].head(10))

# Ratings 1 or 2 → 'negative'
# Rating 3 → 'neutral'
# Ratings 4 or 5 (or anything above 3) → 'positive'
# Out:
#    rating sentiment
# 0       1  negative
# 1       2  negative
# 2       5  positive
# 3       3   neutral
# 4       1  negative
# 5       4  positive
# 6       2  negative
# 7       3   neutral
# 8       1  negative
# 9       2  negative

# %%
 ##save clean csv file
df.to_csv(r'C:\Users\Thennarasu\OneDrive\Documents\dataset\clean.csv', index=False)

# %%
# Count of Each Sentiment
sns.countplot(data=df, x='sentiment', palette='pastel')
plt.title('Sentiment Distribution')
plt.show()
# Out:
# C:\Users\Thennarasu\AppData\Local\Temp\ipykernel_3088\472746610.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='sentiment', palette='pastel')

# %%
# Most Frequent Words (Histogram)
vectorizer = CountVectorizer(stop_words='english', max_features=20)
X = vectorizer.fit_transform(df['review'])

# Convert to DataFrame
word_freq = pd.DataFrame({
    'word': vectorizer.get_feature_names_out(),
    'frequency': X.toarray().sum(axis=0)
})

# Plot
sns.barplot(data=word_freq.sort_values(by='frequency', ascending=False), x='frequency', y='word', palette='Blues_r')
plt.title('Top 20 Most Frequent Words')
plt.show()
# Out:
# C:\Users\Thennarasu\AppData\Local\Temp\ipykernel_3088\601868859.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=word_freq.sort_values(by='frequency', ascending=False), x='frequency', y='word', palette='Blues_r')

# %%
df['sentiment'] = df['sentiment'].map({'negative': 0, 'neutral': 1, 'positive': 2})

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score, confusion_matrix

# Features and target
X_text = df['review']
y = df['sentiment']

# TF-IDF Vectorization
tfidf = TfidfVectorizer(max_features=1000, ngram_range=(1,2), stop_words='english')
X_tfidf = tfidf.fit_transform(X_text)

# SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_tfidf.toarray(), y)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled, test_size=0.3, random_state=42, stratify=y_resampled
)

# %%
# Models
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "Naive Bayes": MultinomialNB()
}

# Loop through models
for name, model in models.items():
    print(f"\n🔹 Model: {name}")
    
    # Fit
    model.fit(X_train, y_train)
    
    # Predict
    y_pred = model.predict(X_test)
    
    # Classification Report
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    
    # Accuracy
    print("Accuracy:", accuracy_score(y_test, y_pred))
    
    # AUC-ROC
    if hasattr(model, "predict_proba"):
        y_proba = model.predict_proba(X_test)
        auc = roc_auc_score(y_test, y_proba, multi_class='ovr')
        print("AUC-ROC Score (OvR):", auc)
    else:
        print("AUC-ROC not available (model does not support probability prediction)")
    
    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f"Confusion Matrix: {name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()
    
    # Cross-validation Accuracy
    scores = cross_val_score(model, X_resampled, y_resampled, cv=5, scoring='accuracy')
    print("Cross-validation Accuracy Scores:", scores)
    print("Mean CV Accuracy:", scores.mean())
# Out:
# 🔹 Model: Logistic Regression
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.17      0.29         6
#            1       0.50      0.67      0.57         6
#            2       0.44      0.67      0.53         6
#
#     accuracy                           0.50        18
#    macro avg       0.65      0.50      0.46        18
# weighted avg       0.65      0.50      0.46        18
#
# Accuracy: 0.5
# AUC-ROC Score (OvR): 0.736111111111111
# Cross-validation Accuracy Scores: [0.83333333 0.41666667 0.33333333 0.66666667 0.75      ]
# Mean CV Accuracy: 0.6
#
# 🔹 Model: Random Forest
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.50      0.55         6
#            1       1.00      0.33      0.50         6
#            2       0.36      0.67      0.47         6
#
#     accuracy                           0.50        18
#    macro avg       0.65      0.50      0.51        18
# weighted avg       0.65      0.50      0.51        18
#
# Accuracy: 0.5
# AUC-ROC Score (OvR): 0.75
# Cross-validation Accuracy Scores: [0.5        0.33333333 0.33333333 0.5        0.75      ]
# Mean CV Accuracy: 0.4833333333333333
#
# 🔹 Model: Naive Bayes
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.17      0.29         6
#            1       0.50      0.67      0.57         6
#            2       0.44      0.67      0.53         6
#
#     accuracy                           0.50        18
#    macro avg       0.65      0.50      0.46        18
# weighted avg       0.65      0.50      0.46        18
#
# Accuracy: 0.5
# AUC-ROC Score (OvR): 0.7453703703703706
# Cross-validation Accuracy Scores: [0.75       0.33333333 0.25       0.58333333 0.75      ]
# Mean CV Accuracy: 0.5333333333333333

# %%
from sklearn.neural_network import MLPClassifier

# Initialize MLP model
mlp_model = MLPClassifier(hidden_layer_sizes=(128, 64),  # two hidden layers
                          activation='relu',
                          solver='adam',
                          max_iter=300,
                          early_stopping=True,
                          n_iter_no_change=10,
                          validation_fraction=0.1,
                          random_state=42)

print("\n🔹 Model: MLPClassifier")

# Fit the model
mlp_model.fit(X_train, y_train)

# Predict on test set
y_pred_mlp = mlp_model.predict(X_test)

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred_mlp))

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_mlp))

# AUC-ROC Score
if hasattr(mlp_model, "predict_proba"):
    y_proba_mlp = mlp_model.predict_proba(X_test)
    auc_mlp = roc_auc_score(y_test, y_proba_mlp, multi_class='ovr')
    print("AUC-ROC Score (OvR):", auc_mlp)
else:
    print("AUC-ROC not available (model does not support probability prediction)")

# Confusion Matrix
cm_mlp = confusion_matrix(y_test, y_pred_mlp)
sns.heatmap(cm_mlp, annot=True, fmt='d', cmap='Greens')
plt.title("Confusion Matrix: MLP Classifier")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Cross-validation (optional)
from sklearn.model_selection import cross_val_score
cv_scores_mlp = cross_val_score(mlp_model, X_resampled, y_resampled, cv=5, scoring='accuracy')
print("Cross-validation Accuracy Scores:", cv_scores_mlp)
print("Mean CV Accuracy:", cv_scores_mlp.mean())
# Out:
# 🔹 Model: MLPClassifier
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.33      1.00      0.50         6
#            2       0.00      0.00      0.00         6
#
#     accuracy                           0.33        18
#    macro avg       0.11      0.33      0.17        18
# weighted avg       0.11      0.33      0.17        18
#
# Accuracy: 0.3333333333333333
# AUC-ROC Score (OvR): 0.5
# e:\data\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# e:\data\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# e:\data\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Cross-validation Accuracy Scores: [0.33333333 0.33333333 0.33333333 0.41666667 0.33333333]
# Mean CV Accuracy: 0.35

# %%
import pickle

# Assuming `model` is your trained LogisticRegression instance
with open('logistic_model.pkl', 'wb') as f:
    pickle.dump(model, f)
print("✅ Logistic Regression model saved!")
# Out:
# ✅ Logistic Regression model saved!

# %%
with open('tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf, f)  # `tfidf` is your trained TfidfVectorizer
print("✅ TF-IDF vectorizer saved!")
# Out:
# ✅ TF-IDF vectorizer saved!
